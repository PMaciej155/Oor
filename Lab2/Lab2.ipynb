# %%
import threading
import urllib
import random
from datetime import datetime
from math import sqrt

# %% [markdown]
# ## Zadanie 2

# %%
def hello(numstring):
    for i in range(12):
        print("hread "+str(numstring)+" says hello \n")

# %%
threads = []  
for numstring in range(8):
    t = threading.Thread(target=hello, args=[numstring])
    threads.append(t)
for thread in threads:
    thread.start()
    thread.join()
# Out:
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# ...

# %% [markdown]
# 2. Drugi program

# %%
threads = []  
for numstring in range(8):
    t = threading.Thread(target=hello, args=[numstring])
    threads.append(t)
    
for thread in threads:
    thread.start()
# Out:
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 0 says hello
#
# hread 1 says hello
# hread 2 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 1 says hello
#
# hread 3 says hello
#
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 3 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# hread 2 says hello
#
# ...
